# %%
import numpy as np
x_train = np.genfromtxt("mnist_small_train_in.txt", delimiter=',', dtype=int)
y_train = np.genfromtxt("mnist_small_train_out.txt", delimiter=',', dtype=int)
x_val = np.genfromtxt("mnist_small_test_in.txt", delimiter=',', dtype=int)
y_val = np.genfromtxt("mnist_small_test_out.txt", delimiter=',', dtype=int)

# %%
print(x_train.shape, y_train.shape)
print(x_val.shape, y_val.shape)
# Out:
# (6006, 784) (6006,)
# (1004, 784) (1004,)

# %%
def sigmoid(x, der=False):
    if der:
        return (np.exp(-x))/((np.exp(-x)+1)**2)
    return 1/(1 + np.exp(-x))

# %%
def softmax(x):
    exps = np.exp(x - x.max())
    return exps / np.sum(exps, axis=0)

# %%
class Neuralnetwork:
    def __init__(self, size, epochs=200, l_rate=1):
        self.size = size
        self.epochs = epochs
        self.l_rate = l_rate
        self.params = self.initialization()
    
    def initialization(self):
        input_layer = self.size[0]
        hidden_layer = self.size[1]
        output_layer = self.size[2]
        params = {
            'W1': np.random.randn(hidden_layer, input_layer) * np.sqrt(1. / input_layer),
            'B1': np.zeros((hidden_layer,1)) * np.sqrt(1. / input_layer),
            'W2': np.random.randn(output_layer, hidden_layer)* np.sqrt(1. / hidden_layer),
            'B2': np.zeros((output_layer,1)) * np.sqrt(1. / hidden_layer),
        }
        return params
    
    def forward(self, x_train):
        params = self.params
        params['A1'] = params['W1'] @ x_train.T + params['B1']
        params['Z1'] = sigmoid(params['A1'])
        params['A2'] = params['W2'] @ params['Z1'] + params['B2']
        params['Z2'] = softmax(params['A2'])
        return params['Z2']
    
    def backward(self, x_train, y_train, output):
        params, n, momentan, change_weight = self.params, x_train.shape[0], .8, {}
        error = output - self.one_hot_encoding(y_train)
        error_A2 = error @ params['Z1'].T
        error_A1 = np.array([x*y for x, y in zip(params['W2'].T @ error, sigmoid(params['Z1'], der=True))])
        change_weight['W2'] = error_A2 / n 
        change_weight['B2'] = error @ np.ones((n,1)) / n
        change_weight['W1'] = error_A1 @ x_train / n
        change_weight['B1'] = error_A1 @ np.ones((n,1)) / n
        
        #optimization parameters with momentan
        change_weight['W2'] = momentan*params['W2'] + (1-momentan)*change_weight['W2']
        change_weight['B2'] = momentan*params['B2'] + (1-momentan)*change_weight['B2']
        change_weight['W1'] = momentan*params['W1'] + (1-momentan)*change_weight['W1']
        change_weight['B1'] = momentan*params['B1'] + (1-momentan)*change_weight['B1']
        
        params['W2'] -= change_weight['W2'] * self.l_rate
        params['B2'] -= change_weight['B2'] * self.l_rate
        params['W1'] -= change_weight['W1'] * self.l_rate
        params['B1'] -= change_weight['B1'] * self.l_rate
        return params
    
    def one_hot_encoding(self, y):
        lst1 = []
        for i in range(10):
            lst2 = []
            for j in range(y.shape[0]):
                if j == y[i]:
                    lst2.append(1)
                else:
                    lst2.append(0)
            lst1.append(lst2)
        return np.array(lst1)     
    
    def accuracy(self, x_val, y_val):
        predict = []
        output = self.forward(x_val).T
        for i in range(y_val.shape[0]):
            pred = np.argmax(output[i])
            #print(pred, y_val[i])
            predict.append(pred!=y_val[i])
        return sum(i for i in predict)/y_val.shape[0]
    
    def train(self, x_train, y_train, x_val, y_val):
        for i in range(self.epochs):
            output = self.forward(x_train)
            weight = self.backward(x_train, y_train, output)
            accur = self.accuracy(x_val, y_val)
            print('Epoch:{0}, Misclassification Rate"{1:.0%}'.format(i+1, accur))
            
nn = Neuralnetwork([784,300,10])
nn.train(x_train, y_train, x_val, y_val)
# Out:
# Epoch:1, Misclassification Rate"90%
# Epoch:2, Misclassification Rate"90%
# Epoch:3, Misclassification Rate"90%
# Epoch:4, Misclassification Rate"90%
# Epoch:5, Misclassification Rate"90%
# Epoch:6, Misclassification Rate"90%
# Epoch:7, Misclassification Rate"90%
# Epoch:8, Misclassification Rate"90%
# Epoch:9, Misclassification Rate"90%
# Epoch:10, Misclassification Rate"90%
# Epoch:11, Misclassification Rate"90%
# Epoch:12, Misclassification Rate"90%
# Epoch:13, Misclassification Rate"90%
# Epoch:14, Misclassification Rate"90%
# Epoch:15, Misclassification Rate"90%
# Epoch:16, Misclassification Rate"90%
# Epoch:17, Misclassification Rate"90%
# Epoch:18, Misclassification Rate"90%
# Epoch:19, Misclassification Rate"90%
# Epoch:20, Misclassification Rate"90%
# Epoch:21, Misclassification Rate"90%
# Epoch:22, Misclassification Rate"90%
# Epoch:23, Misclassification Rate"90%
# Epoch:24, Misclassification Rate"90%
# Epoch:25, Misclassification Rate"90%
# Epoch:26, Misclassification Rate"90%
# Epoch:27, Misclassification Rate"90%
# Epoch:28, Misclassification Rate"90%
# Epoch:29, Misclassification Rate"90%
# Epoch:30, Misclassification Rate"90%
# Epoch:31, Misclassification Rate"90%
# Epoch:32, Misclassification Rate"90%
# Epoch:33, Misclassification Rate"90%
# Epoch:34, Misclassification Rate"90%
# Epoch:35, Misclassification Rate"90%
# Epoch:36, Misclassification Rate"90%
# Epoch:37, Misclassification Rate"90%
# Epoch:38, Misclassification Rate"90%
# Epoch:39, Misclassification Rate"90%
# Epoch:40, Misclassification Rate"90%
# Epoch:41, Misclassification Rate"90%
# Epoch:42, Misclassification Rate"90%
# Epoch:43, Misclassification Rate"90%
# Epoch:44, Misclassification Rate"90%
# Epoch:45, Misclassification Rate"90%
# Epoch:46, Misclassification Rate"90%
# Epoch:47, Misclassification Rate"90%
# Epoch:48, Misclassification Rate"90%
# Epoch:49, Misclassification Rate"90%
# Epoch:50, Misclassification Rate"91%
# Epoch:51, Misclassification Rate"90%
# Epoch:52, Misclassification Rate"91%
# Epoch:53, Misclassification Rate"90%
# Epoch:54, Misclassification Rate"90%
# Epoch:55, Misclassification Rate"90%
# Epoch:56, Misclassification Rate"89%
# Epoch:57, Misclassification Rate"90%
# Epoch:58, Misclassification Rate"91%
# Epoch:59, Misclassification Rate"90%
# Epoch:60, Misclassification Rate"91%
# Epoch:61, Misclassification Rate"90%
# Epoch:62, Misclassification Rate"91%
# Epoch:63, Misclassification Rate"90%
# Epoch:64, Misclassification Rate"90%
# Epoch:65, Misclassification Rate"90%
# Epoch:66, Misclassification Rate"90%
# Epoch:67, Misclassification Rate"90%
# Epoch:68, Misclassification Rate"90%
# Epoch:69, Misclassification Rate"90%
# Epoch:70, Misclassification Rate"90%
# Epoch:71, Misclassification Rate"90%
# Epoch:72, Misclassification Rate"89%
# Epoch:73, Misclassification Rate"90%
# Epoch:74, Misclassification Rate"90%
# Epoch:75, Misclassification Rate"90%
# Epoch:76, Misclassification Rate"90%
# Epoch:77, Misclassification Rate"90%
# Epoch:78, Misclassification Rate"90%
# Epoch:79, Misclassification Rate"90%
# Epoch:80, Misclassification Rate"92%
# Epoch:81, Misclassification Rate"90%
# Epoch:82, Misclassification Rate"90%
# Epoch:83, Misclassification Rate"90%
# Epoch:84, Misclassification Rate"91%
# Epoch:85, Misclassification Rate"90%
# Epoch:86, Misclassification Rate"91%
# Epoch:87, Misclassification Rate"90%
# Epoch:88, Misclassification Rate"91%
# Epoch:89, Misclassification Rate"90%
# Epoch:90, Misclassification Rate"90%
# Epoch:91, Misclassification Rate"90%
# Epoch:92, Misclassification Rate"90%
# Epoch:93, Misclassification Rate"90%
# Epoch:94, Misclassification Rate"91%
# Epoch:95, Misclassification Rate"90%
# Epoch:96, Misclassification Rate"91%
# Epoch:97, Misclassification Rate"90%
# Epoch:98, Misclassification Rate"90%
# Epoch:99, Misclassification Rate"90%
# Epoch:100, Misclassification Rate"89%
# Epoch:101, Misclassification Rate"90%
# Epoch:102, Misclassification Rate"89%
# Epoch:103, Misclassification Rate"90%
# Epoch:104, Misclassification Rate"90%
# Epoch:105, Misclassification Rate"90%
# Epoch:106, Misclassification Rate"90%
# Epoch:107, Misclassification Rate"90%
# Epoch:108, Misclassification Rate"89%
# Epoch:109, Misclassification Rate"90%
# Epoch:110, Misclassification Rate"91%
# Epoch:111, Misclassification Rate"90%
# Epoch:112, Misclassification Rate"91%
# Epoch:113, Misclassification Rate"90%
# Epoch:114, Misclassification Rate"89%
# Epoch:115, Misclassification Rate"90%
# Epoch:116, Misclassification Rate"91%
# Epoch:117, Misclassification Rate"90%
# Epoch:118, Misclassification Rate"92%
# Epoch:119, Misclassification Rate"90%
# Epoch:120, Misclassification Rate"90%
# Epoch:121, Misclassification Rate"90%
# Epoch:122, Misclassification Rate"89%
# Epoch:123, Misclassification Rate"90%
# Epoch:124, Misclassification Rate"89%
# Epoch:125, Misclassification Rate"90%
# Epoch:126, Misclassification Rate"90%
# Epoch:127, Misclassification Rate"90%
# Epoch:128, Misclassification Rate"88%
# Epoch:129, Misclassification Rate"90%
# Epoch:130, Misclassification Rate"90%
# Epoch:131, Misclassification Rate"90%
# Epoch:132, Misclassification Rate"89%
# Epoch:133, Misclassification Rate"90%
# Epoch:134, Misclassification Rate"92%
# Epoch:135, Misclassification Rate"90%
# Epoch:136, Misclassification Rate"90%
# Epoch:137, Misclassification Rate"90%
# Epoch:138, Misclassification Rate"90%
# Epoch:139, Misclassification Rate"90%
# Epoch:140, Misclassification Rate"90%
# Epoch:141, Misclassification Rate"90%
# Epoch:142, Misclassification Rate"90%
# Epoch:143, Misclassification Rate"90%
# Epoch:144, Misclassification Rate"89%
# Epoch:145, Misclassification Rate"90%
# Epoch:146, Misclassification Rate"89%
# Epoch:147, Misclassification Rate"90%
# Epoch:148, Misclassification Rate"89%
# Epoch:149, Misclassification Rate"90%
# Epoch:150, Misclassification Rate"89%
# Epoch:151, Misclassification Rate"90%
# Epoch:152, Misclassification Rate"89%
# Epoch:153, Misclassification Rate"90%
# Epoch:154, Misclassification Rate"88%
# Epoch:155, Misclassification Rate"90%
# Epoch:156, Misclassification Rate"89%
# Epoch:157, Misclassification Rate"90%
# Epoch:158, Misclassification Rate"88%
# Epoch:159, Misclassification Rate"90%
# Epoch:160, Misclassification Rate"88%
# Epoch:161, Misclassification Rate"90%
# Epoch:162, Misclassification Rate"89%
# Epoch:163, Misclassification Rate"90%
# Epoch:164, Misclassification Rate"89%
# Epoch:165, Misclassification Rate"90%
# Epoch:166, Misclassification Rate"89%
# Epoch:167, Misclassification Rate"90%
# Epoch:168, Misclassification Rate"89%
# Epoch:169, Misclassification Rate"90%
# Epoch:170, Misclassification Rate"89%
# Epoch:171, Misclassification Rate"90%
# Epoch:172, Misclassification Rate"88%
# Epoch:173, Misclassification Rate"90%
# Epoch:174, Misclassification Rate"89%
# Epoch:175, Misclassification Rate"90%
# Epoch:176, Misclassification Rate"88%
# Epoch:177, Misclassification Rate"90%
# Epoch:178, Misclassification Rate"89%
# Epoch:179, Misclassification Rate"90%
# Epoch:180, Misclassification Rate"89%
# Epoch:181, Misclassification Rate"90%
# Epoch:182, Misclassification Rate"89%
# Epoch:183, Misclassification Rate"90%
# Epoch:184, Misclassification Rate"89%
# Epoch:185, Misclassification Rate"90%
# Epoch:186, Misclassification Rate"89%
# Epoch:187, Misclassification Rate"90%
# Epoch:188, Misclassification Rate"89%
# Epoch:189, Misclassification Rate"90%
# Epoch:190, Misclassification Rate"89%
# Epoch:191, Misclassification Rate"90%
# Epoch:192, Misclassification Rate"89%
# Epoch:193, Misclassification Rate"90%
# Epoch:194, Misclassification Rate"89%
# Epoch:195, Misclassification Rate"90%
# Epoch:196, Misclassification Rate"89%
# Epoch:197, Misclassification Rate"90%
# Epoch:198, Misclassification Rate"89%
# Epoch:199, Misclassification Rate"90%
# Epoch:200, Misclassification Rate"89%
